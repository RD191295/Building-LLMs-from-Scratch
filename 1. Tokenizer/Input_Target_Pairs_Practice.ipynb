# %% [markdown]
# ### Step 1: Creating Token

# %%
with open(r"D:\Data_Science_Study\Course_Pracitse_Code\GenerativeAi\LLM_From_Scratch\Building-LLMs-from-Scratch\0. Data\the-verdict.txt" , "r" , encoding = "utf-8") as f:
    raw_text = f.read()


print("Total Number of Character:", len(raw_text))
print(raw_text[:99])
# Out:
# Total Number of Character: 20479
# I HAD always thought Jack Gisburn rather a cheap genius--though a good fellow enough--so it was no

# %% [markdown]
# ### Our Aim is to tokenize this 20-479 chracter short story into individual words and special character that we can trun into embedding for LLM training

# %% [markdown]
# ### Split text to Token

# %%
import re
preprocessed = re.split(r'([,._!?:;"()\']|--|\s)', raw_text)
preprocessed = [item for item in preprocessed if item.strip()]

print(len(preprocessed))
print(preprocessed[:35])
# Out:
# 4690
# ['I', 'HAD', 'always', 'thought', 'Jack', 'Gisburn', 'rather', 'a', 'cheap', 'genius', '--', 'though', 'a', 'good', 'fellow', 'enough', '--', 'so', 'it', 'was', 'no', 'great', 'surprise', 'to', 'me', 'to', 'hear', 'that', ',', 'in', 'the', 'height', 'of', 'his', 'glory']

# %% [markdown]
# ### Step :2 Creating Token ID

# %% [markdown]
# ### Creating simple Tokennizer Class

# %%
all_tokens = sorted(list(set(preprocessed)))

all_tokens .extend(["<|endoftext|>","<|unk|>"])

vocab = {token:integer for integer,token in enumerate(all_tokens)}

print(len(vocab.items()))
# Out:
# 1132

# %%
for i,item in enumerate(list(vocab.items())[-5:]):
    print(item)
# Out:
# ('younger', 1127)
# ('your', 1128)
# ('yourself', 1129)
# ('<|endoftext|>', 1130)
# ('<|unk|>', 1131)

# %%
class SimpleTokenizerV2:
    def __init__(self, vocab):
        self.str_to_int = vocab
        self.int_to_str = {i:s for s ,i in vocab.items()}
    

    def encode(self,text):
        preprocessed = re.split(r'([,._!?:;"()\']|--|\s)', text)
        preprocessed = [
            item.strip() for item in preprocessed if item.strip()
        ]
        preprocessed = [
            item if item in self.str_to_int
            else "<|unk|>" for item in preprocessed
        ]

        ids = [self.str_to_int[s] for s in preprocessed]

        return ids
    

    def decode(self,ids):
        text = " ".join([self.int_to_str[i] for i in ids])

        # replace spaces for pamctuations
        text  = re.sub(r'\s+([,.?!"()\'])', r'\1',text)

        return text

# %%
tokenizer = SimpleTokenizerV2(vocab)
tokenizer.encode(raw_text)
# Out:
# [53,
#  44,
#  149,
#  1003,
#  57,
#  38,
#  818,
#  115,
#  256,
#  486,
#  6,
#  1002,
#  115,
#  500,
#  435,
#  392,
#  6,
#  908,
#  585,
#  1077,
#  709,
#  508,
#  961,
#  1016,
#  663,
#  1016,
#  535,
#  987,
#  5,
#  568,
#  988,
#  538,
#  722,
#  549,
#  496,
#  5,
#  533,
#  514,
#  370,
#  549,
#  748,
#  5,
#  661,
#  115,
#  841,
#  1102,
#  5,
#  157,
#  397,
#  547,
#  568,
#  115,
#  1066,
#  727,
#  988,
#  84,
#  7,
#  3,
#  99,
#  53,
#  818,
#  1003,
#  585,
#  1120,
#  530,
#  208,
#  85,
#  734,
#  34,
#  7,
#  4,
#  1,
#  93,
#  538,
#  722,
#  549,
#  496,
#  1,
#  6,
#  987,
#  1077,
#  1089,
#  988,
#  1112,
#  242,
#  585,
#  7,
#  53,
#  244,
#  535,
#  67,
#  7,
#  37,
#  100,
#  6,
#  549,
#  602,
#  25,
#  897,
#  6,
#  326,
#  549,
#  1042,
#  116,
#  7,
#  1,
#  73,
#  297,
#  585,
#  2,
#  850,
#  498,
#  1016,
#  866,
#  988,
#  1059,
#  722,
#  697,
#  769,
#  2,
#  1083,
#  1051,
#  9,
#  239,
#  53,
#  359,
#  2,
#  970,
#  998,
#  722,
#  987,
#  5,
#  66,
#  7,
#  83,
#  6,
#  988,
#  646,
#  1016,
#  16,
#  584,
#  145,
#  53,
#  998,
#  722,
#  7,
#  1,
#  93,
#  1116,
#  5,
#  727,
#  67,
#  7,
#  100,
#  2,
#  850,
#  633,
#  5,
#  693,
#  586,
#  114,
#  847,
#  114,
#  177,
#  1002,
#  994,
#  1088,
#  827,
#  568,
#  156,
#  389,
#  1069,
#  722,
#  677,
#  7,
#  14,
#  585,
#  1077,
#  711,
#  731,
#  988,
#  67,
#  7,
#  101,
#  1097,
#  688,
#  7,
#  45,
#  711,
#  988,
#  410,
#  50,
#  28,
#  5,
#  180,
#  988,
#  602,
#  40,
#  36,
#  882,
#  5,
#  929,
#  663,
#  209,
#  38,
#  2,
#  850,
#  1,
#  65,
#  1,
#  1016,
#  856,
#  5,
#  1108,
#  976,
#  568,
#  539,
#  417,
#  8,
#  1,
#  107,
#  875,
#  711,
#  642,
#  1053,
#  586,
#  628,
#  140,
#  1,
#  10,
#  108,
#  0,
#  6,
#  399,
#  1007,
#  988,
#  795,
#  722,
#  50,
#  2,
#  850,
#  976,
#  53,
#  436,
#  117,
#  1016,
#  418,
#  988,
#  420,
#  1108,
#  395,
#  7,
#  80,
#  57,
#  38,
#  0,
#  93,
#  1112,
#  514,
#  654,
#  546,
#  6,
#  585,
#  1077,
#  444,
#  987,
#  994,
#  879,
#  687,
#  546,
#  7,
#  13,
#  549,
#  742,
#  872,
#  438,
#  829,
#  1088,
#  536,
#  5,
#  157,
#  568,
#  549,
#  742,
#  1026,
#  528,
#  115,
#  694,
#  7,
#  81,
#  589,
#  10,
#  79,
#  7,
#  54,
#  585,
#  1088,
#  5,
#  988,
#  553,
#  722,
#  988,
#  299,
#  1077,
#  1067,
#  241,
#  635,
#  26,
#  72,
#  5,
#  1097,
#  5,
#  568,
#  145,
#  500,
#  425,
#  5,
#  234,
#  738,
#  568,
#  988,
#  21,
#  115,
#  1065,
#  523,
#  1,
#  717,
#  1,
#  727,
#  57,
#  6,
#  729,
#  722,
#  1001,
#  884,
#  175,
#  927,
#  1108,
#  817,
#  977,
#  987,
#  53,
#  530,
#  536,
#  3,
#  53,
#  1113,
#  2,
#  970,
#  856,
#  241,
#  1099,
#  4,
#  281,
#  1016,
#  38,
#  2,
#  850,
#  748,
#  7,
#  14,
#  908,
#  6,
#  549,
#  838,
#  213,
#  165,
#  583,
#  6,
#  988,
#  345,
#  505,
#  337,
#  738,
#  5,
#  157,
#  5,
#  177,
#  67,
#  7,
#  100,
#  514,
#  786,
#  5,
#  988,
#  792,
#  722,
#  1,
#  39,
#  1,
#  1087,
#  1051,
#  7,
#  56,
#  1077,
#  711,
#  1010,
#  1004,
#  1123,
#  604,
#  987,
#  5,
#  568,
#  988,
#  297,
#  722,
#  115,
#  437,
#  1085,
#  2,
#  565,
#  727,
#  988,
#  84,
#  5,
#  585,
#  950,
#  720,
#  1016,
#  663,
#  1016,
#  1114,
#  1100,
#  38,
#  514,
#  491,
#  1051,
#  549,
#  748,
#  7,
#  75,
#  828,
#  5,
#  585,
#  821,
#  1077,
#  115,
#  981,
#  796,
#  7,
#  102,
#  125,
#  549,
#  1103,
#  1120,
#  530,
#  208,
#  1020,
#  375,
#  6,
#  549,
#  424,
#  898,
#  514,
#  208,
#  325,
#  988,
#  909,
#  722,
#  857,
#  987,
#  67,
#  7,
#  38,
#  514,
#  1,
#  364,
#  546,
#  362,
#  7,
#  1,
#  35,
#  67,
#  7,
#  38,
#  6,
#  177,
#  949,
#  6,
#  514,
#  711,
#  408,
#  1010,
#  702,
#  115,
#  1122,
#  138,
#  57,
#  2,
#  850,
#  838,
#  514,
#  208,
#  973,
#  7,
#  56,
#  671,
#  198,
#  987,
#  533,
#  514,
#  661,
#  539,
#  6,
#  895,
#  533,
#  629,
#  549,
#  373,
#  6,
#  205,
#  533,
#  336,
#  2,
#  970,
#  1074,
#  1016,
#  497,
#  727,
#  748,
#  9,
#  239,
#  585,
#  1120,
#  530,
#  208,
#  527,
#  1016,
#  801,
#  987,
#  533,
#  514,
#  491,
#  1051,
#  549,
#  748,
#  205,
#  533,
#  514,
#  661,
#  539,
#  7,
#  73,
#  297,
#  5,
#  566,
#  876,
#  514,
#  711,
#  364,
#  546,
#  362,
#  5,
#  876,
#  514,
#  394,
#  5,
#  177,
#  62,
#  28,
#  288,
#  5,
#  422,
#  1016,
#  1,
#  624,
#  546,
#  1051,
#  1,
#  6,
#  876,
#  514,
#  711,
#  615,
#  546,
#  191,
#  1016,
#  988,
#  374,
#  7,
#  102,
#  806,
#  988,
#  236,
#  579,
#  549,
#  521,
#  140,
#  6,
#  1089,
#  115,
#  1070,
#  456,
#  115,
#  1103,
#  0,
#  22,
#  67,
#  7,
#  38,
#  167,
#  1016,
#  530,
#  347,
#  585,
#  6,
#  157,
#  53,
#  436,
#  585,
#  671,
#  198,
#  578,
#  1016,
#  440,
#  738,
#  1100,
#  7,
#  93,
#  332,
#  622,
#  722,
#  988,
#  84,
#  618,
#  587,
#  1016,
#  949,
#  804,
#  124,
#  916,
#  9,
#  157,
#  532,
#  5,
#  727,
#  697,
#  1083,
#  1016,
#  64,
#  24,
#  5,
#  250,
#  115,
#  494,
#  722,
#  57,
#  2,
#  850,
#  195,
#  984,
#  218,
#  988,
#  771,
#  5,
#  53,
#  514,
#  698,
#  224,
#  1000,
#  988,
#  708,
#  315,
#  7,
#  53,
#  469,
#  988,
#  296,
#  180,
#  975,
#  215,
#  989,
#  751,
#  9,
#  157,
#  67,
#  7,
#  38,
#  2,
#  850,
#  1086,
#  1077,
#  908,
#  485,
#  987,
#  5,
#  568,
#  988,
#  393,
#  1085,
#  5,
#  53,
#  268,
#  585,
#  475,
#  7,
#  56,
#  1077,
#  711,
#  987,
#  697,
#  555,
#  1077,
#  1,
#  578,
#  1,
#  8,
#  727,
#  987,
#  779,
#  53,
#  292,
#  530,
#  491,
#  62,
#  28,
#  988,
#  479,
#  824,
#  7,
#  56,
#  1077,
#  590,
#  205,
#  876,
#  1077,
#  114,
#  711,
#  114,
#  578,
#  6,
#  566,
#  53,
#  662,
#  198,
#  755,
#  988,
#  237,
#  6,
#  987,
#  53,
#  469,
#  539,
#  908,
#  7,
#  35,
#  57,
#  5,
#  145,
#  549,
#  622,
#  5,
#  514,
#  208,
#  963,
#  241,
#  578,
#  1112,
#  8,
#  994,
#  514,
#  468,
#  549,
#  174,
#  5,
#  585,
#  514,
#  208,
#  822,
#  568,
#  988,
#  556,
#  722,
#  989,
#  133,
#  7,
#  14,
#  585,
#  1077,
#  993,
#  577,
#  1016,
#  712,
#  1089,
#  378,
#  988,
#  1,
#  318,
#  181,
#  722,
#  665,
#  1,
#  3,
#  53,
#  814,
#  62,
#  28,
#  4,
#  1077,
#  532,
#  727,
#  546,
#  7,
#  53,
#  530,
#  667,
#  987,
#  67,
#  7,
#  38,
#  1077,
#  841,
#  9,
#  157,
#  585,
#  1077,
#  567,
#  764,
#  987,
#  539,
#  562,
#  1077,
#  414,
#  477,
#  999,
#  266,
#  115,
#  323,
#  239,
#  947,
#  853,
#  7,
#  56,
#  584,
#  5,
#  177,
#  115,
#  848,
#  5,
#  988,
#  763,
#  1097,
#  859,
#  681,
#  1097,
#  488,
#  686,
#  738,
#  722,
#  585,
#  9,
#  157,
#  57,
#  2,
#  850,
#  384,
#  346,
#  722,
#  549,
#  1103,
#  2,
#  850,
#  219,
#  193,
#  387,
#  546,
#  5,
#  1108,
#  156,
#  166,
#  722,
#  765,
#  501,
#  5,
#  1016,
#  1027,
#  585,
#  579,
#  719,
#  722,
#  174,
#  157,
#  652,
#  7,
#  102,
#  988,
#  605,
#  5,
#  53,
#  696,
#  129,
#  5,
#  533,
#  831,
#  830,
#  570,
#  9,
#  239,
#  533,
#  1077,
#  240,
#  82,
#  233,
#  157,
#  382,
#  770,
#  1108,
#  115,
#  344,
#  987,
#  216,
#  988,
#  154,
#  839,
#  7,
#  1,
#  63,
#  2,
#  850,
#  731,
#  406,
#  584,
#  1016,
#  806,
#  203,
#  579,
#  265,
#  5,
#  1,
#  1077,
#  729,
#  722,
#  988,
#  189,
#  533,
#  598,
#  362,
#  127,
#  988,
#  87,
#  157,
#  890,
#  722,
#  156,
#  411,
#  168,
#  651,
#  5,
#  1090,
#  5,
#  727,
#  115,
#  604,
#  315,
#  5,
#  53,
#  514,
#  140,
#  849,
#  741,
#  477,
#  64,
#  24,
#  9,
#  157,
#  67,
#  7,
#  38,
#  5,
#  199,
#  727,
#  546,
#  5,
#  130,
#  456,
#  697,
#  391,
#  8,
#  1,
#  57,
#  584,
#  908,
#  684,
#  868,
#  1016,
#  403,
#  464,
#  722,
#  203,
#  7,
#  1,
#  80,
#  57,
#  0,
#  56,
#  514,
#  149,
#  208,
#  549,
#  431,
#  ...]

# %% [markdown]
# ### Some more token can be added :
# ### <BOS> : Begining of text
# ### <EOS> : End of text
# ### [PAD] : Padding ( batch may have varriying length so to see batch have same length of text size we can agument [PAD] etc)

# %% [markdown]
# ### Byte Pair Encoding

# %%
import tiktoken

# %%
tokenizer  = tiktoken.get_encoding('gpt2')

# %%
integers = tokenizer.encode(raw_text , allowed_special={"<|endoftext|>"})
print(integers)
# Out:
# [40, 367, 2885, 1464, 1807, 3619, 402, 271, 10899, 2138, 257, 7026, 15632, 438, 2016, 257, 922, 5891, 1576, 438, 568, 340, 373, 645, 1049, 5975, 284, 502, 284, 3285, 326, 11, 287, 262, 6001, 286, 465, 13476, 11, 339, 550, 5710, 465, 12036, 11, 6405, 257, 5527, 27075, 11, 290, 4920, 2241, 287, 257, 4489, 64, 319, 262, 34686, 41976, 13, 357, 10915, 314, 2138, 1807, 340, 561, 423, 587, 10598, 393, 28537, 2014, 198, 198, 1, 464, 6001, 286, 465, 13476, 1, 438, 5562, 373, 644, 262, 1466, 1444, 340, 13, 314, 460, 3285, 9074, 13, 46606, 536, 5469, 438, 14363, 938, 4842, 1650, 353, 438, 2934, 489, 3255, 465, 48422, 540, 450, 67, 3299, 13, 366, 5189, 1781, 340, 338, 1016, 284, 3758, 262, 1988, 286, 616, 4286, 705, 1014, 510, 26, 475, 314, 836, 470, 892, 286, 326, 11, 1770, 13, 8759, 2763, 438, 1169, 2994, 284, 943, 17034, 318, 477, 314, 892, 286, 526, 383, 1573, 11, 319, 9074, 13, 536, 5469, 338, 11914, 11, 33096, 663, 4808, 3808, 62, 355, 996, 484, 547, 12548, 287, 281, 13079, 410, 12523, 286, 22353, 13, 843, 340, 373, 407, 691, 262, 9074, 13, 536, 48819, 508, 25722, 276, 13, 11161, 407, 262, 40123, 18113, 544, 9325, 701, 11, 379, 262, 938, 402, 1617, 261, 12917, 905, 11, 5025, 502, 878, 402, 271, 10899, 338, 366, 31640, 12, 67, 20811, 1, 284, 910, 11, 351, 10953, 287, 607, 2951, 25, 366, 1135, 2236, 407, 804, 2402, 663, 588, 757, 13984, 198, 198, 5779, 28112, 10197, 832, 262, 46475, 286, 18113, 544, 338, 10953, 314, 2936, 1498, 284, 1986, 262, 1109, 351, 1602, 11227, 414, 13, 23676, 3619, 402, 271, 10899, 0, 383, 1466, 550, 925, 683, 438, 270, 373, 15830, 326, 484, 815, 25722, 683, 13, 9754, 465, 898, 1714, 7380, 30090, 547, 2982, 11, 290, 287, 465, 898, 3292, 8941, 257, 4636, 28582, 13, 18612, 35394, 30, 8673, 13, 1002, 340, 547, 11, 262, 15393, 286, 262, 5977, 373, 29178, 3474, 416, 1310, 40559, 11959, 1636, 11, 508, 11, 287, 477, 922, 4562, 11, 3181, 503, 287, 262, 37090, 257, 845, 22665, 366, 672, 270, 2838, 1, 319, 3619, 438, 505, 286, 883, 905, 88, 6685, 42070, 351, 4738, 6276, 871, 326, 314, 423, 2982, 357, 40, 1839, 470, 910, 416, 4150, 8, 3688, 284, 402, 271, 10899, 338, 12036, 13, 843, 523, 438, 14363, 10568, 852, 5729, 11331, 18893, 540, 438, 1169, 5114, 11835, 3724, 503, 11, 290, 11, 355, 9074, 13, 536, 5469, 550, 11001, 11, 262, 2756, 286, 366, 38, 271, 10899, 82, 1, 1816, 510, 13, 198, 198, 1026, 373, 407, 10597, 1115, 812, 1568, 326, 11, 287, 262, 1781, 286, 257, 1178, 2745, 6, 4686, 1359, 319, 262, 34686, 41976, 11, 340, 6451, 5091, 284, 502, 284, 4240, 1521, 402, 271, 10899, 550, 1813, 510, 465, 12036, 13, 1550, 14580, 11, 340, 1107, 373, 257, 29850, 1917, 13, 1675, 24456, 465, 3656, 561, 423, 587, 1165, 2562, 438, 14363, 3148, 1650, 1010, 550, 587, 6699, 262, 1540, 558, 286, 2282, 326, 9074, 13, 402, 271, 10899, 550, 366, 7109, 14655, 683, 866, 526, 1114, 9074, 13, 402, 271, 10899, 438, 292, 884, 438, 18108, 407, 11196, 10597, 3016, 257, 614, 706, 3619, 338, 10568, 550, 587, 2077, 13, 632, 1244, 307, 326, 339, 550, 6405, 607, 438, 20777, 339, 8288, 465, 10152, 438, 13893, 339, 1422, 470, 765, 284, 467, 319, 12036, 26, 475, 340, 561, 423, 587, 1327, 284, 5879, 326, 339, 550, 1813, 510, 465, 12036, 780, 339, 550, 6405, 607, 13, 198, 198, 5189, 1781, 11, 611, 673, 550, 407, 17901, 683, 866, 11, 673, 550, 8603, 11, 355, 4544, 9325, 701, 42397, 11, 4054, 284, 366, 26282, 683, 510, 1, 438, 7091, 550, 407, 2957, 683, 736, 284, 262, 1396, 417, 13, 1675, 1234, 262, 14093, 656, 465, 1021, 757, 438, 10919, 257, 410, 5040, 329, 257, 3656, 0, 887, 9074, 13, 402, 271, 10899, 4120, 284, 423, 595, 67, 1328, 340, 438, 392, 314, 2936, 340, 1244, 307, 3499, 284, 1064, 503, 1521, 13, 198, 198, 464, 748, 586, 652, 1204, 286, 262, 34686, 41976, 37733, 2346, 284, 884, 14177, 8233, 1020, 5768, 26, 290, 1719, 11, 319, 616, 835, 284, 22489, 40089, 11, 4978, 257, 19350, 286, 3619, 338, 3652, 436, 81, 5286, 8812, 2114, 1022, 262, 279, 1127, 11, 314, 550, 3589, 28068, 294, 1555, 262, 1306, 1110, 13, 198, 198, 40, 1043, 262, 3155, 379, 8887, 1106 ...

# %% [markdown]
# ## Create INPUT Target Pairs

# %%
context_size = 4 # length of input

x = integers[:context_size]
y = integers[1:context_size+1]


print(f"x: {x}")
print(f"y:     {y}")
# Out:
# x: [40, 367, 2885, 1464]
# y:     [367, 2885, 1464, 1807]

# %%
for i in range(1, context_size+1):
    context = integers[:i]
    desired = integers[i]

    print(context , "----->" , desired)
# Out:
# [40] -----> 367
# [40, 367] -----> 2885
# [40, 367, 2885] -----> 1464
# [40, 367, 2885, 1464] -----> 1807

# %%
for i in range(1, context_size+1):
    context = integers[:i]
    desired = integers[i]

    print(tokenizer.decode(context) , "----->" , tokenizer.decode([desired]))
# Out:
# I ----->  H
# I H -----> AD
# I HAD ----->  always
# I HAD always ----->  thought

# %% [markdown]
# ### Implementing Data Loader

# %%
from torch.utils.data import Dataset, DataLoader
import torch

class GPTDatasetV1(Dataset):
    def __init__(self, txt, tokenizer, max_length, stride):
        self.input_ids  = []
        self.target_ids = []

        # tokenize the entire text
        token_ids = tokenizer.encode(txt,allowed_special={"<|endoftext|>"})

        # use sliding window
        for i in range(0,len(token_ids)- max_length, stride):
            input_chunk = token_ids[i:i+max_length]
            target_chunk = token_ids[i+1: i+max_length +1]
            self.input_ids.append(torch.tensor(input_chunk))
            self.target_ids.append(torch.tensor(target_chunk))

        
    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return self.input_ids[idx], self.target_ids[idx]

# %%
def create_dataloader_v1(txt, batch_size = 4, max_length = 256,
                         stride = 128, shuffle = True,
                         drop_last = True, num_workers = 0):
    

    tokenizer = tiktoken.get_encoding('gpt2')

    dataset = GPTDatasetV1(txt, tokenizer, max_length , stride)

    dataloader = DataLoader(
        dataset,
        batch_size= batch_size,
        shuffle =shuffle,
        drop_last=drop_last,
        num_workers= num_workers
    )

    return dataloader

# %%
dataloader = create_dataloader_v1(
    raw_text, batch_size=8, max_length=4, stride=4, shuffle=False
)

# %%
data_iter = iter(dataloader)

first_batch = next(data_iter)

# %%
print(f"First Batch is : {first_batch}")
print(f"Second Batch is : {next(data_iter)}")
# Out:
# First Batch is : [tensor([[   40,   367,  2885,  1464],
#         [ 1807,  3619,   402,   271],
#         [10899,  2138,   257,  7026],
#         [15632,   438,  2016,   257],
#         [  922,  5891,  1576,   438],
#         [  568,   340,   373,   645],
#         [ 1049,  5975,   284,   502],
#         [  284,  3285,   326,    11]]), tensor([[  367,  2885,  1464,  1807],
#         [ 3619,   402,   271, 10899],
#         [ 2138,   257,  7026, 15632],
#         [  438,  2016,   257,   922],
#         [ 5891,  1576,   438,   568],
#         [  340,   373,   645,  1049],
#         [ 5975,   284,   502,   284],
#         [ 3285,   326,    11,   287]])]
# Second Batch is : [tensor([[  287,   262,  6001,   286],
#         [  465, 13476,    11,   339],
#         [  550,  5710,   465, 12036],
#         [   11,  6405,   257,  5527],
#         [27075,    11,   290,  4920],
#         [ 2241,   287,   257,  4489],
#         [   64,   319,   262, 34686],
#         [41976,    13,   357, 10915]]), tensor([[  262,  6001,   286,   465],
#         [13476,    11,   339,   550],
#         [ 5710,   465, 12036,    11],
#         [ 6405,   257,  5527, 27075],
#         [   11,   290,  4920,  2241],
#         [  287,   257,  4489,    64],
#         [  319,   262, 34686, 41976],
#         [   13,   357, 10915,   314]])]

# %% [markdown]
# ## Token Embedding

# %%
input_ids = torch.tensor([2,3,5,1])

# %%
vocab_size = 6
output_dim =3


torch.manual_seed(123)
embedding_layer = torch.nn.Embedding(vocab_size, output_dim)

# %%
print(embedding_layer.weight)
# Out:
# Parameter containing:
# tensor([[ 0.3374, -0.1778, -0.1690],
#         [ 0.9178,  1.5810,  1.3010],
#         [ 1.2753, -0.2010, -0.1606],
#         [-0.4015,  0.9666, -1.1481],
#         [-1.1589,  0.3255, -0.6315],
#         [-2.8400, -0.7849, -1.4096]], requires_grad=True)

# %%
print(embedding_layer(torch.tensor([3])))
# Out:
# tensor([[-0.4015,  0.9666, -1.1481]], grad_fn=<EmbeddingBackward0>)

# %%
print(embedding_layer(torch.tensor([2,3,5,1])))
# Out:
# tensor([[ 1.2753, -0.2010, -0.1606],
#         [-0.4015,  0.9666, -1.1481],
#         [-2.8400, -0.7849, -1.4096],
#         [ 0.9178,  1.5810,  1.3010]], grad_fn=<EmbeddingBackward0>)

# %% [markdown]
# ### Positional Embedding

# %%
vocab_size = 50257
output_dim = 256

token_embedding_layer = torch.nn.Embedding(vocab_size , output_dim)

# %%
token_embedding_layer.weight.shape
# Out:
# torch.Size([50257, 256])

# %%
dataloader = create_dataloader_v1(
    raw_text, batch_size=8, max_length=4, stride=4, shuffle=False
)

data_iter = iter(dataloader)

inputs, targets = next(data_iter)

# %%
print("Token IDs:\n", inputs)
print("Input Shape:\n", inputs.shape)
# Out:
# Token IDs:
#  tensor([[   40,   367,  2885,  1464],
#         [ 1807,  3619,   402,   271],
#         [10899,  2138,   257,  7026],
#         [15632,   438,  2016,   257],
#         [  922,  5891,  1576,   438],
#         [  568,   340,   373,   645],
#         [ 1049,  5975,   284,   502],
#         [  284,  3285,   326,    11]])
# Input Shape:
#  torch.Size([8, 4])

# %%
token_embeddings = token_embedding_layer(inputs)

print("Token Embedding Shape\n", token_embeddings.shape)
# Out:
# Token Embedding Shape
#  torch.Size([8, 4, 256])

# %%
token_embeddings
# Out:
# tensor([[[ 0.4913,  1.1239,  1.4588,  ..., -0.3995, -1.8735, -0.1445],
#          [ 0.4481,  0.2536, -0.2655,  ...,  0.4997, -1.1991, -1.1844],
#          [-0.2507, -0.0546,  0.6687,  ...,  0.9618,  2.3737, -0.0528],
#          [ 0.9457,  0.8657,  1.6191,  ..., -0.4544, -0.7460,  0.3483]],
#
#         [[ 1.5460,  1.7368, -0.7848,  ..., -0.1004,  0.8584, -0.3421],
#          [-1.8622, -0.1914, -0.3812,  ...,  1.1220, -0.3496,  0.6091],
#          [ 1.9847, -0.6483, -0.1415,  ..., -0.3841, -0.9355,  1.4478],
#          [ 0.9647,  1.2974, -1.6207,  ...,  1.1463,  1.5797,  0.3969]],
#
#         [[-0.7713,  0.6572,  0.1663,  ..., -0.8044,  0.0542,  0.7426],
#          [ 0.8046,  0.5047,  1.2922,  ...,  1.4648,  0.4097,  0.3205],
#          [ 0.0795, -1.7636,  0.5750,  ...,  2.1823,  1.8231, -0.3635],
#          [ 0.4267, -0.0647,  0.5686,  ..., -0.5209,  1.3065,  0.8473]],
#
#         ...,
#
#         [[-1.6156,  0.9610, -2.6437,  ..., -0.9645,  1.0888,  1.6383],
#          [-0.3985, -0.9235, -1.3163,  ..., -1.1582, -1.1314,  0.9747],
#          [ 0.6089,  0.5329,  0.1980,  ..., -0.6333, -1.1023,  1.6292],
#          [ 0.3677, -0.1701, -1.3787,  ...,  0.7048,  0.5028, -0.0573]],
#
#         [[-0.1279,  0.6154,  1.7173,  ...,  0.3789, -0.4752,  1.5258],
#          [ 0.4861, -1.7105,  0.4416,  ...,  0.1475, -1.8394,  1.8755],
#          [-0.9573,  0.7007,  1.3579,  ...,  1.9378, -1.9052, -1.1816],
#          [ 0.2002, -0.7605, -1.5170,  ..., -0.0305, -0.3656, -0.1398]],
#
#         [[-0.9573,  0.7007,  1.3579,  ...,  1.9378, -1.9052, -1.1816],
#          [-0.0632, -0.6548, -1.0296,  ..., -0.9538, -0.5026, -0.1128],
#          [ 0.6032,  0.8983,  2.0722,  ...,  1.5242,  0.2030, -0.3002],
#          [ 1.1274, -0.1082, -0.2195,  ...,  0.5059, -1.8138, -0.0700]]],
#        grad_fn=<EmbeddingBackward0>)

# %%
context_length = 4
pos_embedding_layer =  torch.nn.Embedding(context_length, output_dim)
pos_embedding_layer.weight
# Out:
# Parameter containing:
# tensor([[-2.0049,  0.5874, -0.4354,  ...,  0.7926, -0.0893, -0.5755],
#         [ 0.2844,  0.6477, -0.0762,  ...,  0.7396,  0.0491,  1.3986],
#         [ 0.9397,  0.9033, -0.2303,  ...,  0.4648, -0.8137, -0.3211],
#         [ 0.8994,  0.4214, -0.0861,  ...,  0.0078, -1.9325,  0.2861]],
#        requires_grad=True)

# %%
pos_embeddings = pos_embedding_layer(torch.arange(context_length))
print(pos_embeddings.shape)
# Out:
# torch.Size([4, 256])

# %%
final_embeddin_layer = token_embeddings + pos_embeddings
final_embeddin_layer.shape
# Out:
# torch.Size([8, 4, 256])

# %%
final_embeddin_layer
# Out:
# tensor([[[-1.5136,  1.7113,  1.0235,  ...,  0.3931, -1.9628, -0.7200],
#          [ 0.7324,  0.9013, -0.3417,  ...,  1.2393, -1.1500,  0.2142],
#          [ 0.6890,  0.8486,  0.4385,  ...,  1.4266,  1.5599, -0.3739],
#          [ 1.8451,  1.2871,  1.5330,  ..., -0.4467, -2.6785,  0.6344]],
#
#         [[-0.4588,  2.3243, -1.2201,  ...,  0.6922,  0.7691, -0.9176],
#          [-1.5778,  0.4563, -0.4574,  ...,  1.8616, -0.3004,  2.0076],
#          [ 2.9244,  0.2550, -0.3717,  ...,  0.0807, -1.7493,  1.1267],
#          [ 1.8641,  1.7188, -1.7068,  ...,  1.1540, -0.3528,  0.6830]],
#
#         [[-2.7762,  1.2446, -0.2691,  ..., -0.0117, -0.0351,  0.1671],
#          [ 1.0889,  1.1524,  1.2160,  ...,  2.2044,  0.4588,  1.7191],
#          [ 1.0192, -0.8603,  0.3447,  ...,  2.6471,  1.0093, -0.6846],
#          [ 1.3260,  0.3567,  0.4825,  ..., -0.5131, -0.6260,  1.1334]],
#
#         ...,
#
#         [[-3.6204,  1.5485, -3.0791,  ..., -0.1718,  0.9995,  1.0629],
#          [-0.1141, -0.2758, -1.3925,  ..., -0.4185, -1.0822,  2.3733],
#          [ 1.5486,  1.4362, -0.0323,  ..., -0.1685, -1.9160,  1.3081],
#          [ 1.2671,  0.2513, -1.4648,  ...,  0.7126, -1.4298,  0.2287]],
#
#         [[-2.1328,  1.2029,  1.2819,  ...,  1.1715, -0.5645,  0.9503],
#          [ 0.7705, -1.0628,  0.3654,  ...,  0.8871, -1.7902,  3.2741],
#          [-0.0176,  1.6039,  1.1277,  ...,  2.4026, -2.7190, -1.5027],
#          [ 1.0995, -0.3391, -1.6031,  ..., -0.0228, -2.2981,  0.1463]],
#
#         [[-2.9622,  1.2881,  0.9226,  ...,  2.7304, -1.9945, -1.7570],
#          [ 0.2212, -0.0071, -1.1058,  ..., -0.2142, -0.4535,  1.2858],
#          [ 1.5429,  1.8016,  1.8419,  ...,  1.9890, -0.6107, -0.6213],
#          [ 2.0268,  0.3132, -0.3056,  ...,  0.5137, -3.7463,  0.2161]]],
#        grad_fn=<AddBackward0>)
